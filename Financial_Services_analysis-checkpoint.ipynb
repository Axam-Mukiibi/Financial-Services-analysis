# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
finances = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\Data Science\Python Data Trials\Financial_Services.csv')

# %%
finances.describe()
# Out:
#         Unnamed: 0       rating
# count  8970.000000  8950.000000
# mean   4484.500000     3.799140
# std    2589.560291     0.988408
# min       0.000000     1.000000
# 25%    2242.250000     3.300000
# 50%    4484.500000     4.000000
# 75%    6726.750000     4.500000
# max    8969.000000     5.000000

# %%
finances.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8970 entries, 0 to 8969
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      8970 non-null   int64
#  1   name            8970 non-null   object
#  2   rating          8950 non-null   float64
#  3   reviews         8970 non-null   object
#  4   company_type    8032 non-null   object
#  5   Head_Quarters   6044 non-null   object
#  6   Company_Age     4092 non-null   object
#  7   No_of_Employee  2332 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 560.8+ KB

# %%
finances.head(5)
# Out:
#    Unnamed: 0              name  rating          reviews company_type  \
# 0           0        ICICI Bank     4.0  (33.6k Reviews)       Public
# 1           1         HDFC Bank     4.0  (37.9k Reviews)       Public
# 2           2  HCL Technologies     3.9  (17.4k Reviews)       Public
# 3           3         Axis Bank     3.9  (18.3k Reviews)       Public
# 4           4               IBM     4.2  (20.7k Reviews)       Public
#
#                     Head_Quarters    Company_Age             No_of_Employee
# 0  Mumbai,Maharashtra + 1020 more   28 years old  1 Lakh+ Employees (India)
# 1  Mumbai,Maharashtra + 1168 more   28 years old  1 Lakh+ Employees (India)
# 2  Noida,Uttar Pradesh + 138 more   31 years old  1 Lakh+ Employees (India)
# 3  Mumbai,Maharashtra + 1041 more   29 years old  1 Lakh+ Employees (India)
# 4      Armonk,New York + 115 more  111 years old  1 Lakh+ Employees (India)

# %%
finances.isnull()
# Out:
#       Unnamed: 0   name  rating  reviews  company_type  Head_Quarters  \
# 0          False  False   False    False         False          False
# 1          False  False   False    False         False          False
# 2          False  False   False    False         False          False
# 3          False  False   False    False         False          False
# 4          False  False   False    False         False          False
# ...          ...    ...     ...      ...           ...            ...
# 8965       False  False   False    False         False           True
# 8966       False  False   False    False         False           True
# 8967       False  False   False    False         False          False
# 8968       False  False   False    False         False           True
# 8969       False  False   False    False         False          False
#
#       Company_Age  No_of_Employee
# 0           False           False
# 1           False           False
# ...

# %%
finances.isnull().sum()
# Out:
# Unnamed: 0           0
# name                 0
# rating              20
# reviews              0
# company_type       938
# Head_Quarters     2926
# Company_Age       4878
# No_of_Employee    6638
# dtype: int64

# %%
finances['rating'].fillna(finances['rating'].mean(),inplace=True)

# %%
finances.isnull().sum()
# Out:
# Unnamed: 0           0
# name                 0
# rating               0
# reviews              0
# company_type       938
# Head_Quarters     2926
# Company_Age       4878
# No_of_Employee    6638
# dtype: int64

# %%
finances['rating'].max()
# Out:
# 5.0

# %%
finances.loc[(finances['rating']>=5)]
# Out:
#       Unnamed: 0                 name  rating       reviews company_type  \
# 1113        1113         UnlistedGuru     5.0  (36 Reviews)          LLP
# 1367        1367  Centurion Bank o...     5.0  (29 Reviews)       Public
# 1743        1743  Digital Marketin...     5.0  (21 Reviews)      Kolkata
# 1772        1772  Digital Marketin...     5.0  (21 Reviews)      Kolkata
# 1803        1803  Orbex Technologi...     5.0  (20 Reviews)      Private
# ...          ...                  ...     ...           ...          ...
# 8958        8958         Vanilla Moon     5.0   (1 Reviews)    New Delhi
# 8961        8961  R2S Events & Ent...     5.0   (1 Reviews)    New Delhi
# 8962        8962  Theta Measuremen...     5.0   (1 Reviews)         Pune
# 8966        8966  Musqot Marketing...     5.0   (1 Reviews)    Stockholm
# 8967        8967            W4Consult     5.0   (1 Reviews)    New Delhi
#
#            Head_Quarters   Company_Age            No_of_Employee
# ...

# %%
finances.value_counts()
# Out:
# Unnamed: 0  name                 rating  reviews          company_type  Head_Quarters                   Company_Age   No_of_Employee
# 0           ICICI Bank           4.0     (33.6k Reviews)  Public        Mumbai,Maharashtra + 1020 more  28 years old  1 Lakh+ Employees (India)    1
# 2785        Infomerics Valua...  3.9     (12 Reviews)     Private       Delhi/NCR,Delhi + 3 more        36 years old  51-200 Employees (India)     1
# 2925        Findability Scie...  4.4     (11 Reviews)     LLC           Woburn,Massachusetts + 1 more   12 years old  11-50 Employees (India)      1
# 2929        Kyzer Software       3.8     (11 Reviews)     Private       Mumbai,Maharashtra              6 years old   51-200 Employees (Global)    1
# 2935        Leads Insurance ...  4.4     (11 Reviews)     Private       Bareilly + 1 more               12 years old  51-200 Employees (Global)    1
# ...

# %%
finances.nunique()
# Out:
# Unnamed: 0        8970
# name              7340
# rating              42
# reviews            397
# company_type       931
# Head_Quarters     1497
# Company_Age        169
# No_of_Employee      22
# dtype: int64

# %%
finances.drop_duplicates()
# Out:
#       Unnamed: 0                 name  rating          reviews company_type  \
# 0              0           ICICI Bank     4.0  (33.6k Reviews)       Public
# 1              1            HDFC Bank     4.0  (37.9k Reviews)       Public
# 2              2     HCL Technologies     3.9  (17.4k Reviews)       Public
# 3              3            Axis Bank     3.9  (18.3k Reviews)       Public
# 4              4                  IBM     4.2  (20.7k Reviews)       Public
# ...          ...                  ...     ...              ...          ...
# 8965        8965  Cellent Technolo...     3.0      (1 Reviews)       Mumbai
# 8966        8966  Musqot Marketing...     5.0      (1 Reviews)    Stockholm
# 8967        8967            W4Consult     5.0      (1 Reviews)    New Delhi
# 8968        8968  Shastra Micro Sy...     1.0      (1 Reviews)    Hyderabad
# 8969        8969  Catallyst Conste...     2.0      (1 Reviews)    Ahmedabad
#
# ...

# %%
sns.barplot(x='name',y='rating',data = finances)
plt.figure(figsize=(10,50))
